# %% [markdown]
# # Lab 1 Introduction to NumPy and Matplotlib

# %%
# !wget -nc -qq -O love_and_peace.jpg "https://www.dropbox.com/scl/fi/dhdl7rh8wc4qd9hxby7yr/love_and_peace.jpg?rlkey=897tkmozj8todanxvgghsgm3e&dl=1"

import imageio
image = imageio.imread('/home/jude/fall_2026/csc_4888/labs/lab_01/love_and_peace.jpg')
print(image[0])

# %% [markdown]
# # Exercises

# %% [markdown]
# 1. Load the image `love_and_peace.jpg`.  Print the first row of the image.  (Display the numbers, don't `imshow()` it.  By "row", I mean the first row of tuples representing the RGB pixels.)

# %%
import matplotlib.pyplot as plt
import imageio

image = imageio.imread('/home/jude/fall_2026/csc_4888/labs/lab_01/love_and_peace.jpg')
row = image[0:1, :, :]

# print(row.shape)
plt.imshow(row)
plt.show()
# Out:
# /tmp/ipykernel_125213/3546522458.py:4: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread('/home/jude/fall_2026/csc_4888/labs/lab_01/love_and_peace.jpg')

# %% [markdown]
# 2. Now `imshow()` the first row of the image.  Why does it appear as a column, rather than a row?  Can you change your code so that it appears as a row of RGB pixels?
#
# *Hint: look at the shape of the array after taking the first row.*

# %%
import imageio
import matplotlib.pyplot as plt
image = imageio.imread('love_and_peace.jpg')
center = image[1222:1478, 1222:1478, :]
# 1350 +- 128
# 1222
# 1478
plt.imshow(center)
plt.show()
# Out:
# /tmp/ipykernel_717296/2362996283.py:3: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread('love_and_peace.jpg')

# %% [markdown]
# 2. Crop out a 256x256 square patch from the center of the image and show it.  (By "crop out" I mean extract or copy pixels from the image.)

# %%
import imageio
import matplotlib.pyplot as plt
import numpy as np
image = imageio.imread('love_and_peace.jpg')
# original image shape
shape_y, shape_x, shape_color = image.shape # (y, x, color)

# get the left half of the image
left_half = image[:, 0:(int)(shape_y/2), :]

# concatinate?
print(f"image: {image.shape}")
print(f"left: {left_half.shape}")
out = np.concatenate([image, left_half], axis=1)
plt.imshow(out)
plt.show()

# %% [markdown]
# 3. Make a new image where you copy the left half of the image and paste it on the right side (so that the new width is 1.5 times the old width).

# %% [markdown]
# 4. Repeat the image nine times in a 3x3 square pattern.  Try to do this using a NumPy function, not using a for loop or list comprehension!
#
# *Hint: see `np.tile`.*

# %%
import imageio
import matplotlib.pyplot as plt
import numpy as np
image = imageio.imread('love_and_peace.jpg')

row = np.tile(image, (3, 3, 1)) # multiply x and y axix by 3, but keep the rgb dimension the same

plt.imshow(row)
plt.show()

# %% [markdown]
# 5. Reverse the order of the third axis and show the result (this will swap the red and blue color channels).
#
# *Hint: you can reverse an axis with `::-1`*

# %%
import imageio
import matplotlib.pyplot as plt
import numpy as np
image = imageio.imread('love_and_peace.jpg')

image = image[:, :, ::-1]

plt.imshow(image)
plt.show()

# %% [markdown]
# 6. Multiply the image by two and show the result.  (I mean multiply the values in the array by two.)  Why does the data type of the image matter here?
#
# *Hint: by "data type" I am referring to the `dtype` of the array.*

# %%
import imageio
import matplotlib.pyplot as plt
import numpy as np
image = imageio.imread('love_and_peace.jpg')

image = image * 2
plt.imshow(image)
plt.show()

# If multiplying by 2 overflows the dtype of the numpy array, then unexpected values might come out.
# Out:
# /tmp/ipykernel_717296/1280673600.py:4: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread('love_and_peace.jpg')
